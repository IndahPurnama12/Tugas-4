# %% [markdown]
# <a href="https://colab.research.google.com/github/IndahPurnama12/Tugas-4/blob/main/ubah_format_foto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Install dependencies
# !pip install pillow pyheif

# 3. Konversi .heic ke .jpg secara rekursif
import os
import pyheif
from PIL import Image

# Ganti path ini sesuai dengan nama folder utama Anda di Google Drive
base_folder = '/content/drive/MyDrive/Dataset_tugas 4'

# Fungsi untuk konversi HEIC ke JPG
def convert_heic_to_jpg(heic_path, jpg_path):
    try:
        heif_file = pyheif.read(heic_path)
        image = Image.frombytes(
            heif_file.mode,
            heif_file.size,
            heif_file.data,
            "raw",
            heif_file.mode,
            heif_file.stride,
        )
        image.save(jpg_path, "JPEG")
        print(f"✔️ Converted: {heic_path} -> {jpg_path}")
    except Exception as e:
        print(f"❌ Failed to convert {heic_path}: {e}")

# Menelusuri folder dan memproses file HEIC
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.lower().endswith(".heic"):
            heic_path = os.path.join(root, file)
            jpg_path = os.path.splitext(heic_path)[0] + ".jpg"
            convert_heic_to_jpg(heic_path, jpg_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# ✔️ Converted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152145(0).heic -> /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152145(0).jpg
# ✔️ Converted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152039.heic -> /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152039.jpg
# ✔️ Converted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151947.heic -> /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151947.jpg
# ✔️ Converted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151612.heic -> /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151612.jpg
# ✔️ Converted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151601.heic -> /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151601.jpg
# ...

# %%
import os

# Path ke folder "Tugas 3" di Google Drive
base_folder = '/content/drive/MyDrive/Dataset_tugas 4'

# Inisialisasi counter
jpg_count = 0

# Telusuri semua file dalam folder dan subfolder
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.lower().endswith('.jpg'):
            jpg_count += 1

print(f"Jumlah file .jpg di dalam folder 'Dataset_tugas 4': {jpg_count}")
# Out:
# Jumlah file .jpg di dalam folder 'Dataset_tugas 4': 600

# %%
import os

# Path ke folder induk
base_folder = '/content/drive/MyDrive/Dataset_tugas 4'

# Hapus semua file .heic secara rekursif
deleted_count = 0

for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.lower().endswith('.heic'):
            file_path = os.path.join(root, file)
            try:
                os.remove(file_path)
                deleted_count += 1
                print(f"🗑️ Deleted: {file_path}")
            except Exception as e:
                print(f"❌ Failed to delete {file_path}: {e}")

print(f"\nTotal file .heic yang dihapus: {deleted_count}")
# Out:
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152145(0).heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_152039.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151947.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151612.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151601.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151516.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151501.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151137.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151451.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151146.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151448.heic
# 🗑️ Deleted: /content/drive/MyDrive/Dataset_tugas 4/Snack/20250519_151152.heic
# ...

# %%
import os

# Path ke folder "Tugas 3" di Google Drive
base_folder = '/content/drive/MyDrive/Dataset_tugas 4'

# Inisialisasi counter
jpg_count = 0

# Telusuri semua file dalam folder dan subfolder
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.lower().endswith('.heic'):
            jpg_count += 1

print(f"Jumlah file .jpg di dalam folder 'Dataset_tugas 4': {jpg_count}")
# Out:
# Jumlah file .jpg di dalam folder 'Dataset_tugas 4': 0
